# %%
feature_fraction =0.80000000000000016
learning_rate = 0.01
max_depth = 10
min_samples_leaf = 10
min_split_gain = 0.60000000000000009
n_estimators = 1200

# %%
features = ['입항시간', '입항요일', '입항분기', '입항계절', '선사', '총톤수', '양적하물량', 'Shift']

#선사, 선명 -> 총톤수
#ETA = 접안예정일시
#양적하 물량 = 양하 + 적하
#Shift
